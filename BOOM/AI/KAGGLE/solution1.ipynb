# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("tourism2_revision2.csv")
exam_sub=pd.read_csv("example_submission.csv")

# %%
exam_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Columns: 793 entries, m1 to q427
# dtypes: float64(793)
# memory usage: 148.8 KB

# %%
exam_sub.head()
# Out:
#             m1             m2            m3            m4            m5  \
# 0  6915.352392   96967.290552  62547.906551  25694.867843  19971.179320
# 1  4274.168124   75936.835382  54862.037556  28761.182605  18929.440132
# 2  3288.396137  105144.699692  46562.219602  34665.899482  20564.975288
# 3  1955.642067   91997.077844  45393.998069  31213.567128  24566.735115
# 4  2692.196359   84142.771622  43412.685266  32954.026610  32446.559253
#
#              m6            m7            m8           m9          m10  ...  \
# 0   7918.341729  51561.408007  53389.811442  3667.153146  8682.980525  ...
# 1   6195.426685  42993.475320  53342.443332  2144.906278  8807.951261  ...
# 2   6351.382887  46693.688791  53356.192913  1983.994253  5503.699516  ...
# 3   8843.048440  70982.243438  53795.983618  2044.311626  6523.830157  ...
# 4  10934.997475  72424.492689  38464.637488  3502.724050  7150.737791  ...
#
#            q418           q419          q420          q421           q422  \
# 0  8.513130e+04   21511.181292  8.082066e+04  10255.250965   14128.181319
# 1  7.730135e+05  176626.679547  8.064889e+05  26257.350425   84240.941659
# 2  1.347328e+06  263673.711712  1.125288e+06  56687.389299  147478.958534
# 3  2.536164e+05   52980.517592  2.934975e+05  20508.143068   23334.192975
# 4  9.248491e+04   23875.549544  8.026091e+04  10918.853549   17424.850558
#
#             q423           q424          q425          q426          q427
# 0   22203.526936    3438.722927   1304.443256  23139.958609   5374.509035
# 1  185352.485859  204517.717747  52985.113647  82740.641269  16509.025987
# 2  305710.536882  273157.674768  88365.171690  91025.199096  16791.304185
# 3   68574.266945   33985.100758  24094.194038  38509.940962   6257.134028
# 4   23139.264799    5097.424870   1993.004035  21457.927919   5803.889189
#
# [5 rows x 793 columns]

# %%
exam_sub["m1"].plot(kind='line')
exam_sub["m2"].plot(kind='line')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Columns: 795 entries, m1 to Unnamed: 794
# dtypes: float64(627), int64(168)
# memory usage: 1.9 MB

# %%
data.head()
# Out:
#    m1  m2  m3  m4      m5      m6       m7      m8     m9    m10  ...  q420  \
# 0 NaN NaN NaN NaN     NaN     NaN      NaN     NaN    NaN    NaN  ...   NaN
# 1 NaN NaN NaN NaN     NaN     NaN      NaN     NaN    NaN    NaN  ...   NaN
# 2 NaN NaN NaN NaN     NaN     NaN      NaN     NaN    NaN    NaN  ...   NaN
# 3 NaN NaN NaN NaN   734.0  2777.0   9741.0  7590.0  270.0   12.0  ...   NaN
# 4 NaN NaN NaN NaN  1254.0  4699.0  15599.0  5574.0  276.0  144.0  ...   NaN
#
#    q421  q422  q423  q424  q425  q426  q427  Unnamed: 793  Unnamed: 794
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN           NaN           NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN           NaN           NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN           NaN           NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN           NaN           NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN           NaN           NaN
#
# [5 rows x 795 columns]

# %%
data.tail()
# Out:
#           m1        m2       m3       m4       m5       m6       m7       m8  \
# 304  1979.11   83880.0  52703.0  27909.0  24499.0  11212.0  77558.0  23481.0
# 305  2824.26   83259.0  44670.0  27280.0  22353.0  11044.0  86847.0  40593.0
# 306  3076.51  114520.0  48786.0  34167.0  18417.0   7121.0  46214.0  46766.0
# 307  3402.59  102524.0  55822.0  29644.0  22305.0   5896.0  29034.0  32141.0
# 308  5985.83   88651.0  51138.0  33120.0  30724.0   4739.0  30122.0  42206.0
#
#          m9     m10  ...       q420     q421      q422      q423      q424  \
# 304  2216.0  8447.0  ...   241821.0  12712.0    7235.0   51396.0   29685.0
# 305  2996.0  7086.0  ...    55710.0   7797.0     634.0   14176.0    1507.0
# 306  2240.0  7650.0  ...   715301.0  23746.0   64089.0  174935.0  172695.0
# 307  2072.0  6519.0  ...  1099360.0  47845.0  143869.0  299465.0  260846.0
# 308  3618.0  7664.0  ...   266144.0  17517.0   17690.0   59763.0   32569.0
#
#         q425     q426     q427  Unnamed: 793  Unnamed: 794
# 304  17672.0  35826.0   5455.0           NaN           NaN
# 305    757.0  28076.0   7158.0           NaN           NaN
# 306  49557.0  82520.0  14683.0           NaN           NaN
# 307  79102.0  72956.0  15386.0           NaN           NaN
# 308  19921.0  35810.0   5569.0           NaN           NaN
#
# [5 rows x 795 columns]

# %%
data=data.iloc[:,:-2]
data.head()
# Out:
#    m1  m2  m3  m4      m5      m6       m7      m8     m9    m10  ...  q418  \
# 0 NaN NaN NaN NaN     NaN     NaN      NaN     NaN    NaN    NaN  ...   NaN
# 1 NaN NaN NaN NaN     NaN     NaN      NaN     NaN    NaN    NaN  ...   NaN
# 2 NaN NaN NaN NaN     NaN     NaN      NaN     NaN    NaN    NaN  ...   NaN
# 3 NaN NaN NaN NaN   734.0  2777.0   9741.0  7590.0  270.0   12.0  ...   NaN
# 4 NaN NaN NaN NaN  1254.0  4699.0  15599.0  5574.0  276.0  144.0  ...   NaN
#
#    q419  q420  q421  q422  q423  q424  q425  q426  q427
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 793 columns]

# %%
data.tail()
# Out:
#           m1        m2       m3       m4       m5       m6       m7       m8  \
# 304  1979.11   83880.0  52703.0  27909.0  24499.0  11212.0  77558.0  23481.0
# 305  2824.26   83259.0  44670.0  27280.0  22353.0  11044.0  86847.0  40593.0
# 306  3076.51  114520.0  48786.0  34167.0  18417.0   7121.0  46214.0  46766.0
# 307  3402.59  102524.0  55822.0  29644.0  22305.0   5896.0  29034.0  32141.0
# 308  5985.83   88651.0  51138.0  33120.0  30724.0   4739.0  30122.0  42206.0
#
#          m9     m10  ...       q418      q419       q420     q421      q422  \
# 304  2216.0  8447.0  ...   191521.0   37208.0   241821.0  12712.0    7235.0
# 305  2996.0  7086.0  ...    38355.0   14641.0    55710.0   7797.0     634.0
# 306  2240.0  7650.0  ...   663581.0  166433.0   715301.0  23746.0   64089.0
# 307  2072.0  6519.0  ...  1123497.0  260252.0  1099360.0  47845.0  143869.0
# 308  3618.0  7664.0  ...   218810.0   44875.0   266144.0  17517.0   17690.0
#
#          q423      q424     q425     q426     q427
# 304   51396.0   29685.0  17672.0  35826.0   5455.0
# 305   14176.0    1507.0    757.0  28076.0   7158.0
# 306  174935.0  172695.0  49557.0  82520.0  14683.0
# 307  299465.0  260846.0  79102.0  72956.0  15386.0
# 308   59763.0   32569.0  19921.0  35810.0   5569.0
#
# [5 rows x 793 columns]

# %%
data.shape
# Out:
# (309, 793)

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# q239    287
# q126    272
# q13     271
# q12     271
# q11     271
#        ...
# m245      0
# m246      0
# m247      0
# m248      0
# m249      0
# Length: 793, dtype: int64

# %%
no_null_columns=data.isnull().sum()[data.isnull().sum() == 0].index

# %%
no_null_columns
# Out:
# Index(['m38', 'm39', 'm40', 'm41', 'm42', 'm43', 'm44', 'm45', 'm46', 'm47',
#        ...
#        'm348', 'm349', 'm350', 'm351', 'm352', 'm353', 'm354', 'm355', 'm356',
#        'm357'],
#       dtype='object', length=168)

# %%
# visualization of m1 column
month_1=data["m1"]
month_1.isna().sum()
# Out:
# np.int64(146)

# %%
month_1=month_1.fillna(-100)
month_1
# Out:
# 0      -100.00
# 1      -100.00
# 2      -100.00
# 3      -100.00
# 4      -100.00
#         ...
# 304    1979.11
# 305    2824.26
# 306    3076.51
# 307    3402.59
# 308    5985.83
# Name: m1, Length: 309, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.xlabel=month_1.plot(kind='line')
plt.title("Columns of m1")
plt.show()

# %%
month_2=data["m2"]
month_2.isna().sum()
# Out:
# np.int64(69)

# %%
month_2.fillna(-100)
plt.figure(figsize=(15,5))
plt.xlabel=month_1.plot(kind='line')
plt.title("Columns of m1")
plt.show()

# %%
col=data["q239"]
col=col.fillna(-100)
plt.figure(figsize=(15,5))
plt.xlabel=col.plot(kind='line')
plt.show()

# %%
def plot_col(col_name="m338"):
    col=data.loc[:,col_name]
    col=col.fillna(-100)
    plt.figure(figsize=(15,5))
    plt.xlabel=col.plot(kind='line')
    plt.show()
plot_col()

# %%
data.columns
# Out:
# Index(['m1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10',
#        ...
#        'q418', 'q419', 'q420', 'q421', 'q422', 'q423', 'q424', 'q425', 'q426',
#        'q427'],
#       dtype='object', length=793)

# %%
col=data.loc[:,"m338"]
col=col.fillna(-100).iloc[:60]
plt.figure(figsize=(15,5))
plt.xlabel=col.plot(kind='line')
plt.title("first 60 data of m338")
plt.show()

# %%
plot_col("m330")

# %%
plot_col("m38")

# %%
plot_col("m39")

# %%
# XGBoost on column m38
import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal=sns.color_palette()

# %%
data_m38=data["m38"]
data_m38.shape
# Out:
# (309,)
